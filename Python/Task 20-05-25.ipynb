# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_excel(r"D:\Intership\Python\12-05-25\practice_data.xlsx")
data1 = pd.DataFrame(Data)
data1
# Out:
#     EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0            1    Male            Sales            20             High
# 1            2  Female        Marketing            22           Medium
# 2            3    Male  Human Resources            25             High
# 3            4    Male      Engineering            19              Low
# 4            5  Female          Finance            23           Medium
# 5            6    Male            Sales            21             High
# 6            7  Female        Marketing            24              Low
# 7            8    Male  Human Resources            18           Medium
# 8            9    Male      Engineering            20             High
# 9           10  Female          Finance            22           Medium
# 10          11    Male            Sales            25             High
# 11          12  Female        Marketing            19              Low
# 12          13    Male  Human Resources            23           Medium
# 13          14    Male      Engineering            21             High
# 14          15  Female          Finance            24              Low
# 15          16    Male            Sales            18           Medium
# 16          17  Female        Marketing            20             High
# 17          18    Male  Human Resources            22           Medium
# 18          19    Male      Engineering            25             High
# 19          20  Female          Finance            19              Low
# 20          21    Male            Sales            23           Medium
# 21          22  Female        Marketing            21             High
# 22          23    Male  Human Resources            24              Low
# 23          24    Male      Engineering            18           Medium
# 24          25  Female          Finance            20             High
# 25          26  Female          Finance            19              Low
# 26          27    Male            Sales            23           Medium
# 27          28  Female        Marketing            21             High
# 28          29    Male  Human Resources            24              Low
# 29          30    Male      Engineering            18           Medium
# 30          31  Female          Finance            20             High
#
#    Meeting Project Deadlines  Task Completion Rates  \
# 0                        Yes                     85
# 1                        Yes                     90
# 2                         No                     80
# 3                        Yes                     75
# 4                        Yes                     85
# 5                        Yes                     95
# 6                         No                     70
# 7                        Yes                     80
# 8                        Yes                     90
# 9                        Yes                     85
# 10                        No                     75
# 11                       Yes                     70
# 12                       Yes                     80
# 13                       Yes                     90
# 14                        No                     65
# 15                       Yes                     75
# 16                       Yes                     85
# 17                       Yes                     80
# 18                        No                     70
# 19                       Yes                     65
# 20                       Yes                     75
# 21                       Yes                     85
# 22                        No                     60
# 23                       Yes                     70
# 24                       Yes                     80
# 25                       Yes                     65
# 26                       Yes                     75
# 27                       Yes                     85
# 28                        No                     60
# 29                       Yes                     70
# 30                       Yes                     80
#
#     Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                             8                              7
# 1                             7                              6
# 2                             9                              8
# 3                             6                              5
# 4                             7                              7
# 5                             8                              8
# 6                             5                              4
# 7                             6                              6
# 8                             8                              7
# 9                             7                              6
# 10                            9                              8
# 11                            6                              5
# 12                            7                              7
# 13                            8                              8
# 14                            5                              4
# 15                            6                              6
# 16                            8                              7
# 17                            7                              6
# 18                            9                              8
# 19                            6                              5
# 20                            7                              7
# 21                            8                              8
# 22                            5                              4
# 23                            6                              6
# 24                            8                              7
# 25                            6                              5
# 26                            7                              7
# 27                            8                              8
# 28                            5                              4
# 29                            6                              6
# 30                            8                              7
#
#     Sales Revenue Generated churned
# 0                     51638      No
# 1                     97797     Yes
# 2                     95341      No
# 3                     91806      No
# 4                     64247     Yes
# 5                     89988      No
# 6                     70934     Yes
# 7                     96578      No
# 8                     74219      No
# 9                     87009     Yes
# 10                    77785      No
# 11                    97201     Yes
# 12                    67730      No
# 13                    93427      No
# 14                    77172     Yes
# 15                    85737      No
# 16                    74871     Yes
# 17                    63245      No
# 18                    53169      No
# 19                    81770     Yes
# 20                    78482      No
# 21                    57836     Yes
# 22                    62885      No
# 23                    52579      No
# 24                    75795     Yes
# 25                    81770     Yes
# 26                    78482      No
# 27                    57836     Yes
# 28                    62885      No
# 29                    52579      No
# 30                    75795     Yes

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(x)

# %%
x=data1[['Task Completion Rates']]
y=data1[["Interpersonal Skills Rating"]]
x_train, x_test, y_train, y_test = train_test_split(scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mape = mean_squared_error(y_test, y_pred)
print("Mean squared error:", mape)
# Out:
# Mean squared error: 0.2564152308872768

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mape = mean_squared_error(y_test, y_pred) 
print("Mean squared error:", mape)
# Out:
# Mean squared error: 0.526626984126984

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # RandomForestRegressor

# %%
model = RandomForestRegressor()
model.fit(x_train, y_train.values.ravel())
y_pred = model.predict(x_test)
mape = mean_squared_error(y_test, y_pred)
print("Mean squared error:", mape)
# Out:
# Mean squared error: 0.4509179064063439

# %% [markdown]
# # Task 20/05/25

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model = LogisticRegression()
model.fit(x_train, y_train.values.ravel())
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.7142857142857143

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.14285714285714285

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train.values.ravel())
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.5714285714285714
